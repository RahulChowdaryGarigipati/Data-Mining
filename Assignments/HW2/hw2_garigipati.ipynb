# %%
import pandas as pd

# %%
df = pd.read_csv('BreastCancerCoimbra.csv')

# %%
df
# Out:
#      Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  \
# 0     48  23.500000       70    2.707  0.467409   8.8071     9.702400
# 1     83  20.690495       92    3.115  0.706897   8.8438     5.429285
# 2     82  23.124670       91    4.498  1.009651  17.9393    22.432040
# 3     68  21.367521       77    3.226  0.612725   9.8827     7.169560
# 4     86  21.111111       92    3.549  0.805386   6.6994     4.819240
# ..   ...        ...      ...      ...       ...      ...          ...
# 111   45  26.850000       92    3.330  0.755688  54.6800    12.100000
# 112   62  26.840000      100    4.530  1.117400  12.4500    21.420000
# 113   65  32.050000       97    5.730  1.370998  61.4800    22.540000
# 114   72  25.590000       82    2.820  0.570392  24.9600    33.750000
# 115   86  27.180000      138   19.910  6.777364  90.2800    14.110000
#
#      Resistin    MCP.1  Classification
# 0     7.99585  417.114               1
# 1     4.06405  468.786               1
# ...

# %% [markdown]
# ## Calculating mean, standard deviation, minimum, and maximum values of BMI

# %%
df['BMI'].mean()
# Out:
# 27.582110827413796

# %%
df['BMI'].std()
# Out:
# 5.020135768568435

# %%
df['BMI'].min()
# Out:
# 18.37

# %%
df['BMI'].max()
# Out:
# 38.57875854

# %% [markdown]
# ##  Pearson’s correlation between pairs of attributes

# %%
df.corr(method='pearson')
# Out:
#                      Age       BMI   Glucose   Insulin      HOMA    Leptin  \
# Age             1.000000  0.008530  0.230106  0.032495  0.127033  0.102626
# BMI             0.008530  1.000000  0.138845  0.145295  0.114480  0.569593
# Glucose         0.230106  0.138845  1.000000  0.504653  0.696212  0.305080
# Insulin         0.032495  0.145295  0.504653  1.000000  0.932198  0.301462
# HOMA            0.127033  0.114480  0.696212  0.932198  1.000000  0.327210
# Leptin          0.102626  0.569593  0.305080  0.301462  0.327210  1.000000
# Adiponectin    -0.219813 -0.302735 -0.122121 -0.031296 -0.056337 -0.095389
# Resistin        0.002742  0.195350  0.291327  0.146731  0.231101  0.256234
# MCP.1           0.013462  0.224038  0.264879  0.174356  0.259529  0.014009
# Classification -0.043555 -0.132586  0.384315  0.276804  0.284012 -0.001078
#
#                 Adiponectin  Resistin     MCP.1  Classification
# Age               -0.219813  0.002742  0.013462       -0.043555
# ...

# %% [markdown]
# ## Histogram for each of the quantitative attributes by discretizing it into 10 separate bins and counting the frequency for each bin

# %%
df_quant = df.drop(columns='Classification')
histograms = df_quant.hist(figsize=(20,20),bins=10)

# %% [markdown]
# ##  Boxplot to show the distribution of values for each attribute

# %%
boxplot = df.boxplot('Age')

# %%
boxplot = df.boxplot('BMI')

# %%
boxplot = df.boxplot('Glucose')

# %%
boxplot = df.boxplot('Insulin')

# %%
boxplot = df.boxplot('HOMA')

# %%
boxplot = df.boxplot('Leptin')

# %%
boxplot = df.boxplot('Adiponectin')

# %%
boxplot = df.boxplot('Resistin')

# %%
boxplot = df.boxplot('MCP.1')

# %%
boxplot = df_quant.boxplot(figsize=(20,20))

# %% [markdown]
# Glucose, Insulin, HDMA, Leptin, Adiponectin and Resistin have outliers

# %% [markdown]
# ##  To Display a Scatter Plot and to show the possible correlations observed

# %%
ax = df.plot.scatter(x='Age',y='BMI',figsize=(10,10))

# %%
ax = df.plot.scatter(x='Age',y='Glucose',figsize=(10,10))

# %%
ax = df.plot.scatter(x='Age',y='Insulin',figsize=(10,10))

# %%
ax = df.plot.scatter(x='BMI',y='Glucose',figsize=(10,10))

# %%
ax = df.plot.scatter(x='BMI',y='Insulin',figsize=(10,10))

# %%
ax = df.plot.scatter(x='Glucose',y='Insulin',figsize=(10,10))

# %% [markdown]
# ##  To Use Parallel Co-ordinates to visualize the dataset

# %%
pd.plotting.parallel_coordinates(df, 'Classification', color=('#556270', '#4ECDC4'))
# Out:
# <AxesSubplot:>
